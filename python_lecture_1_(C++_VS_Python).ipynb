# %% [markdown]
# <a href="https://colab.research.google.com/github/ibrahim810/AI_JUST/blob/main/python_lecture_1_(C%2B%2B_VS_Python).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # **Jordan University of Science and Technology (J.U.S.T)**
#
# ### **CS362:Artificial Intelligence**
# #### **Intro to Python Course**
#
# **By: Ibrahim alsharif**
#
# ---

# %% [markdown]
# # C++ VS Python (Syntax)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Software Testing Help:Python Vs C++ | Top 16 Differences Between C++ And Python](https://www.softwaretestinghelp.com/python-vs-cpp/)

# %% [markdown]
# ##Print

# %% [markdown]
# ---
# ###**C++**

# %% [markdown]
# ```
# #include \<iostream>
# using namespace std;
#
# int main() {
#   cout << "Hello World!";
#   return 0;
# }
# ```

# %% [markdown]
# ---
# ###**Python**

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ##Comments

# %% [markdown]
# ---
# ###**C++**

# %% [markdown]
# **Single-line Comments**
# ```
# // This is a comment
# ```
# **Multi-line Comments**
# ```
# /* This is a comment
# written in
# more than just one line */
# ```

# %% [markdown]
# ---
# ###**Python**

# %%
# This is a comment

# This is a comment
# written in
# more than just one line

"""
This is a comment
written in
more than just one line
"""
# Out:
# '\nThis is a comment\nwritten in\nmore than just one line\n'

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ##Variables

# %% [markdown]
# ---
# ###**C++**

# %% [markdown]
# variable myNum of type int with value 15
# ```
# int myNum = 15;
# cout << myNum;
# ```
# declare variable and assign later
# ```
# int myNum;
# myNum = 15;
# cout << myNum;
# ```
# **Note:**
# ```
# int myNum = 15;
# myNum =  'D';
# cout << myNum;
# ```
# **Output:68**

# %% [markdown]
# ---
# ###**Python**

# %%
x=10

# %%
print(x)
# Out:
# 10

# %%
x='hi'

# %%
x
# Out:
# 'hi'

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ##User Input

# %% [markdown]
# ---
# ###**C++**

# %% [markdown]
# ```
# #include <iostream>
# using namespace std;
#
# int main() {
#   int x;
#   cout << "Type a number: "; // Type a number and press enter
#   cin >> x; // Get user input from the keyboard
#   cout << "Your number is: " << x;
#   return 0;
# }
#
# ```

# %% [markdown]
# ---
# ###**Python**

# %%
x = input('Enter name ')
y = input('Enter country ')
print('Hello',x,'from',y)
# Out:
# Enter name ibrahim
# Enter country jo
# Hello ibrahim from jo

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ##DataTypes

# %% [markdown]
# ---
# ###**C++**

# %% [markdown]
# **Basic data types**
# ```
# int myNum = 5;                      // Integer (whole number)
# float myFloatNum = 5.99;            // Floating point number
# double myDoubleNum = 9.98;          // Floating point number
# char myLetter = 'D';                // Character
# bool myBoolean = true;              // Boolean
# string myText = "Hello";            // String
# string cars[4] = {"Volvo", "BMW"};  // Array of Strings
# int myNum[3] = {10, 20, 30};        // Array of Integers
# ```

# %% [markdown]
# ---
# ###**Python**

# %% [markdown]
# ```
# Text Type: 	 	    str
# Numeric Types: 	 	int, float, complex
# Sequence Types:     	list, tuple, range
# Mapping Type: 	 	 dict
# Set Types: 	    	 set, frozenset
# Boolean Type:  		 bool
# Binary Types: 	 	 bytes, bytearray, memoryview
# ```

# %%
a =range(10)

# %%
a = {'a':5,'b':6}

# %%
a
# Out:
# {'a': 5, 'b': 6}

# %%
type(a)
# Out:
# dict

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ##Loop

# %% [markdown]
# ---
# ###**C++**

# %% [markdown]
# **While loop**
# ```
# int i = 0;
# while (i < 5) {
#   cout << i << "\n";
#   i++;
# }
# ```
# **For loop**
# ```
# for (int i = 0; i < 5; i++) {
#   cout << i << "\n";
# }
# ```

# %% [markdown]
# ---
# ###**Python**

# %%
i = 0
while i < 5:
 print(i)
 i+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
a = range(10,1,-2)
for i in a:
  print(i)
# Out:
# 10
# 8
# 6
# 4
# 2

# %%
a = ['Hi','Welcome','Hello',2,3.4,True,[1,2,3,['Hi']]]
for i in a:
  print(i)
# Out:
# Hi
# Welcome
# Hello
# 2
# 3.4
# True
# [1, 2, 3, ['Hi']]

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ##Condition

# %% [markdown]
# ---
# ###**C++**

# %% [markdown]
# **Else If**
# ```
# int time = 22;
# if (time < 10) {
#   cout << "Good morning.";
# } else if (time < 20) {
#   cout << "Good day.";
# } else {
#   cout << "Good evening.";
# }
# ```

# %% [markdown]
# ---
# ###**Python**

# %%
time = 22
if time < 10:
  print("b is greater than a")
elif time < 20:
  print("Good day.")
else:
  print("Good evening.")
# Out:
# Good evening.

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ##Function

# %% [markdown]
# ---
# ###**C++**

# %% [markdown]
# **Void**
# ```
# void myFunction(string fname) {
#   cout << fname << " Refsnes\n";
# }
# ```
# **return**
# ```
# int myFunction(int x) {
#   return 5 + x;
# }
# ```

# %% [markdown]
# ---
# ###**Python**

# %%
def myFunction(x):
    print('Returned  : ')
    print('Returned  : ')

# %%
print('Returned number : ',myFunction(7))
# Out:
# Returned  :
# Returned  :
# Returned number :  None

# %%
def myFunction(x):
    print(5+x)
    print(5+9+x)
    print(5+7+9+x)

# %%
myFunction(7)
# Out:
# 12
# 21
# 28

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# # Class

# %%
class Myclass1:
    x=5

# %%
object1=Myclass1()

# %%
object1.x
# Out:
# 5

# %%
class Myclass1:
    def __init__(self,name,age):
        self.name = name
        self.age = age

# %%
abc = Myclass1('ibrahim',22)

# %%
abc.name
# Out:
# 'ibrahim'

# %%
abc.age
# Out:
# 22
